# %%
# !pip install scrapy

# %%
# !scrapy startproject notes\_project
# Out:
# Error: scrapy.cfg already exists in /content/notes_project

# %%
# !git clone https://github.com/CatherineNjeNjenga/NoteIt
# Out:
# Cloning into 'NoteIt'...
# ...
